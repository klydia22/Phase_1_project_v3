# %%
import os
print(os.getcwd())
# Out:
# c:\Users\User\AppData\Local\Programs\Microsoft VS Code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
print(os.getcwd())
# Out:
# c:\Users\User\AppData\Local\Programs\Microsoft VS Code

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\User\AppData\Local\Programs\Microsoft VS Code

# %%
def clean_injuries(df):
    injury_cols = [
        "Total.Fatal.Injuries", "Total.Serious.Injuries",
        "Total.Minor.Injuries", "Total.Uninjured"
    ]
    df[injury_cols] = df[injury_cols].fillna(0)
    return df

df = clean_injuries(df)

# %%
from IPython.display import display

def clean_engines(df):
    df["Number.of.Engines"] = df["Number.of.Engines"].fillna(df["Number.of.Engines"].median())
    display(df[["Number.of.Engines"]].head())
    return df

# %%
pd.read_csv(r"c:\Users\User\dsc-phase-1-project-v3/data/Aviation_Data.csv")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19472\3084753212.py:1: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv(r"c:\Users\User\dsc-phase-1-project-v3/data/Aviation_Data.csv")
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0      20001218X45444           Accident      SEA87LA080  1948-10-24
# 1      20001218X45447           Accident      LAX94LA336  1962-07-19
# 2      20061025X01555           Accident      NYC07LA005  1974-08-30
# 3      20001218X45448           Accident      LAX96LA321  1977-06-19
# 4      20041105X01764           Accident      CHI79FA064  1979-08-02
# ...               ...                ...             ...         ...
# 90343  20221227106491           Accident      ERA23LA093  2022-12-26
# 90344  20221227106494           Accident      ERA23LA095  2022-12-26
# 90345  20221227106497           Accident      WPR23LA075  2022-12-26
# ...

# %%
# first 5 rows
df.head()
# Out:
#                           Event.Date      Latitude     Longitude  \
# count                          11968  11968.000000  11968.000000
# mean   2004-09-15 10:17:07.540106880   2702.017531  41495.381300
# min              1974-08-30 00:00:00    -78.016945   -174.296666
# 25%              2003-03-09 00:00:00     33.441111   -116.226945
# 50%              2004-09-10 00:00:00     38.167361    -95.485000
#
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       11968.000000          11968.000000            11968.000000
# mean            1.129679              0.471674                0.205381
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
#
#        Total.Minor.Injuries  Total.Uninjured               Publication.Date
# ...

# %%
#data types and non - null count
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to std
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Date              7 non-null      object
#  1   Latitude                8 non-null      float64
#  2   Longitude               8 non-null      float64
#  3   Number.of.Engines       8 non-null      float64
#  4   Total.Fatal.Injuries    8 non-null      float64
#  5   Total.Serious.Injuries  8 non-null      float64
#  6   Total.Minor.Injuries    8 non-null      float64
#  7   Total.Uninjured         8 non-null      float64
#  8   Publication.Date        7 non-null      object
# dtypes: float64(7), object(2)
# memory usage: 940.0+ bytes

# %%
# list of column names
df.describe()
# Out:
#            Latitude     Longitude  Number.of.Engines  Total.Fatal.Injuries  \
# count  8.000000e+00  8.000000e+00           8.000000              8.000000
# mean   9.280747e+05  7.654107e+06        1497.068707           1514.014124
# std    2.575931e+06  2.101717e+07        4230.895325           4224.334302
# min   -7.801695e+01 -1.742967e+02           0.000000              0.000000
# 25%    3.698580e+01 -1.006705e+02           0.854994              0.000000
# 50%    1.372288e+03  5.942990e+03           1.000000              0.235837
# 75%    3.581779e+04  4.130076e+05           1.847259             37.230987
# max    7.302524e+06  5.965231e+07       11968.000000          11968.000000
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count                8.000000              8.000000         8.000000
# mean              1503.522617           1506.693416      1587.649094
# std               4228.337463           4227.107779      4201.314779
# ...

# %%
# check missing values
df.isnull().sum()
# Out:
# Event.Date                1
# Latitude                  0
# Longitude                 0
# Number.of.Engines         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Publication.Date          1
# dtype: int64

# %%
df = pd.read_csv(r"c:\Users\User\dsc-phase-1-project-v3/data/Aviation_Data.csv", encoding="utf-8")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19472\1528545761.py:1: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"c:\Users\User\dsc-phase-1-project-v3/data/Aviation_Data.csv", encoding="utf-8")

# %%
# remove rows with missing values
df.dropna(inplace=True)

# %%
# replace missing values with 0
df.fillna(0, inplace=True)

# %%
df.isnull().sum()
# Out:
# Event.Date                0
# Latitude                  0
# Longitude                 0
# Number.of.Engines         0
# Total.Fatal.Injuries      0
# Total.Serious.Injuries    0
# Total.Minor.Injuries      0
# Total.Uninjured           0
# Publication.Date          0
# dtype: int64

# %%
# remove duplicates
df.drop_duplicates(inplace=True)

# %%
# convert to datetime
df['Event.Date'] = pd.to_datetime(df['Event.Date'])

# %%
 # Remove leading/trailing spaces
df.columns = df.columns.str.strip()

# %%
# Replace spaces with underscores
df.columns = df.columns.str.replace(' ', '_')

# %%
# Convert to lowercase
df.columns = df.columns.str.lower()

# %%
# rename columns
df.rename(columns={'OldName': 'NewName'}, inplace=True)

# %%
# cleaned data
df.to_csv('cleaned_data.csv', index=False)

# %%
 # Display the first 5 rows
df.head()
# Out:
#                          event.date      latitude     longitude  \
# count 1970-01-01 00:00:00.000011968  11968.000000  11968.000000
# mean  2004-09-15 10:17:07.540106880   2702.017531  41495.381300
# min   1974-08-30 00:00:00.000000000    -78.016945   -174.296666
# 25%   2003-03-09 00:00:00.000000000     33.441111   -116.226945
# 50%   2004-09-10 00:00:00.000000000     38.167361    -95.485000
#
#        number.of.engines  total.fatal.injuries  total.serious.injuries  \
# count       11968.000000          11968.000000            11968.000000
# mean            1.129679              0.471674                0.205381
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
#
#        total.minor.injuries  total.uninjured               publication.date
# count          11968.000000     11968.000000                          11896
# ...

# %%
# Display the first 10 rows
df.head(10)
# Out:
#                          event.date      latitude     longitude  \
# count 1970-01-01 00:00:00.000011968  1.196800e+04  1.196800e+04
# mean  2004-09-15 10:17:07.540106880  2.702018e+03  4.149538e+04
# min   1974-08-30 00:00:00.000000000 -7.801695e+01 -1.742967e+02
# 25%   2003-03-09 00:00:00.000000000  3.344111e+01 -1.162269e+02
# 50%   2004-09-10 00:00:00.000000000  3.816736e+01 -9.548500e+01
# 75%   2006-05-23 00:00:00.000000000  4.255792e+01 -8.201993e+01
# max   2022-11-06 00:00:00.000000000  7.302524e+06  5.965231e+07
#
#        number.of.engines  total.fatal.injuries  total.serious.injuries  \
# count       11968.000000          11968.000000            11968.000000
# mean            1.129679              0.471674                0.205381
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# ...

# %%
# Display the last 5 rows
df.tail()
# Out:
#     event.date      latitude     longitude  number.of.engines  \
# min 1974-08-30 -7.801695e+01 -1.742967e+02                0.0
# 25% 2003-03-09  3.344111e+01 -1.162269e+02                1.0
# 50% 2004-09-10  3.816736e+01 -9.548500e+01                1.0
# 75% 2006-05-23  4.255792e+01 -8.201993e+01                1.0
# max 2022-11-06  7.302524e+06  5.965231e+07                4.0
#
#      total.fatal.injuries  total.serious.injuries  total.minor.injuries  \
# min                   0.0                     0.0                   0.0
# 25%                   0.0                     0.0                   0.0
# 50%                   0.0                     0.0                   0.0
# 75%                   0.0                     0.0                   0.0
# max                 141.0                    59.0                  84.0
#
#      total.uninjured     publication.date
# min              0.0  2001-01-12 00:00:00
# 25%              0.0  2004-03-30 00:00:00
# ...

# %%
# display entire data frame
df
# Out:
#                          event.date      latitude     longitude  \
# count 1970-01-01 00:00:00.000011968  1.196800e+04  1.196800e+04
# mean  2004-09-15 10:17:07.540106880  2.702018e+03  4.149538e+04
# min   1974-08-30 00:00:00.000000000 -7.801695e+01 -1.742967e+02
# 25%   2003-03-09 00:00:00.000000000  3.344111e+01 -1.162269e+02
# 50%   2004-09-10 00:00:00.000000000  3.816736e+01 -9.548500e+01
# 75%   2006-05-23 00:00:00.000000000  4.255792e+01 -8.201993e+01
# max   2022-11-06 00:00:00.000000000  7.302524e+06  5.965231e+07
#
#        number.of.engines  total.fatal.injuries  total.serious.injuries  \
# count       11968.000000          11968.000000            11968.000000
# mean            1.129679              0.471674                0.205381
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.dtypes
# Out:
# Event.Id                   object
# Investigation.Type         object
# Accident.Number            object
# Event.Date                 object
# Location                   object
# Country                    object
# Latitude                   object
# Longitude                  object
# Airport.Code               object
# Airport.Name               object
# Injury.Severity            object
# Aircraft.damage            object
# Aircraft.Category          object
# Registration.Number        object
# Make                       object
# Model                      object
# Amateur.Built              object
# Number.of.Engines         float64
# Engine.Type                object
# FAR.Description            object
# Schedule                   object
# Purpose.of.flight          object
# Air.carrier                object
# Total.Fatal.Injuries      float64
# Total.Serious.Injuries    float64
# Total.Minor.Injuries      float64
# Total.Uninjured           float64
# ...

# %%
df["Event.Date"] = pd.to_datetime(df["Event.Date"], errors="coerce")
df["Publication.Date"] = pd.to_datetime(df["Publication.Date"], errors="coerce")
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_19472\2333778434.py:2: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Publication.Date"] = pd.to_datetime(df["Publication.Date"], errors="coerce")

# %%
df[["Latitude", "Longitude", "Number.of.Engines", "Total.Fatal.Injuries",
    "Total.Serious.Injuries", "Total.Minor.Injuries", "Total.Uninjured"]].isna().sum()
# Out:
# Latitude                  78362
# Longitude                 78374
# Number.of.Engines          7543
# Total.Fatal.Injuries      12860
# Total.Serious.Injuries    13969
# Total.Minor.Injuries      13392
# Total.Uninjured            7371
# dtype: int64

# %%
df["Missing_Coordinates"] = df["Latitude"].isna() | df["Longitude"].isna()

# %%
df.describe()
# Out:
#            Latitude     Longitude  Number.of.Engines  Total.Fatal.Injuries  \
# count  8.000000e+00  8.000000e+00           8.000000              8.000000
# mean   9.280747e+05  7.654107e+06        1497.068707           1514.014124
# std    2.575931e+06  2.101717e+07        4230.895325           4224.334302
# min   -7.801695e+01 -1.742967e+02           0.000000              0.000000
# 25%    3.698580e+01 -1.006705e+02           0.854994              0.000000
# 50%    1.372288e+03  5.942990e+03           1.000000              0.235837
# 75%    3.581779e+04  4.130076e+05           1.847259             37.230987
# max    7.302524e+06  5.965231e+07       11968.000000          11968.000000
#
#        Total.Serious.Injuries  Total.Minor.Injuries  Total.Uninjured
# count                8.000000              8.000000         8.000000
# mean              1503.522617           1506.693416      1587.649094
# std               4228.337463           4227.107779      4201.314779
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to std
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Event.Date              7 non-null      object
#  1   Latitude                8 non-null      float64
#  2   Longitude               8 non-null      float64
#  3   Number.of.Engines       8 non-null      float64
#  4   Total.Fatal.Injuries    8 non-null      float64
#  5   Total.Serious.Injuries  8 non-null      float64
#  6   Total.Minor.Injuries    8 non-null      float64
#  7   Total.Uninjured         8 non-null      float64
#  8   Publication.Date        7 non-null      object
# dtypes: float64(7), object(2)
# memory usage: 640.0+ bytes

# %%
df.head()
# Out:
#                           Event.Date      Latitude     Longitude  \
# count                          11968  11968.000000  11968.000000
# mean   2004-09-15 10:17:07.540106880   2702.017531  41495.381300
# min              1974-08-30 00:00:00    -78.016945   -174.296666
# 25%              2003-03-09 00:00:00     33.441111   -116.226945
# 50%              2004-09-10 00:00:00     38.167361    -95.485000
#
#        Number.of.Engines  Total.Fatal.Injuries  Total.Serious.Injuries  \
# count       11968.000000          11968.000000            11968.000000
# mean            1.129679              0.471674                0.205381
# min             0.000000              0.000000                0.000000
# 25%             1.000000              0.000000                0.000000
# 50%             1.000000              0.000000                0.000000
#
#        Total.Minor.Injuries  Total.Uninjured               Publication.Date
# ...
